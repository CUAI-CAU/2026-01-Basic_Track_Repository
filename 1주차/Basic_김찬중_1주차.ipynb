# %% [markdown]
# ### Numpy ndarray 개요

# %%
# 넘파이 사용을 위해 관례적으로 np라는 별칭으로 라이브러리를 불러온다.
import numpy as np

# %%
# 1차원 ndarray를 생성한다.
array1 = np.array([1,2,3])
print('array1 type:',type(array1))
print('array1 array 형태:',array1.shape)

# 2차원 ndarray를 생성한다.
array2 = np.array([[1,2,3],
                  [2,3,4]])
print('array2 type:',type(array2))
print('array2 array 형태:',array2.shape)

# 행이 1개인 2차원 ndarray도 별도로 생성해 차이를 확인한다.
array3 = np.array([[1,2,3]])
print('array3 type:',type(array3))
print('array3 array 형태:',array3.shape)
# Out:
# array1 type: <class 'numpy.ndarray'>
# array1 array 형태: (3,)
# array2 type: <class 'numpy.ndarray'>
# array2 array 형태: (2, 3)
# array3 type: <class 'numpy.ndarray'>
# array3 array 형태: (1, 3)

# %%
# 각 배열의 차원 수를 ndim 속성으로 확인한다.
print('array1: {0}차원, array2: {1}차원, array3: {2}차원'.format(array1.ndim,array2.ndim,array3.ndim))
# Out:
# array1: 1차원, array2: 2차원, array3:  2차원

# %%
# 일반 파이썬 리스트를 만든다.
list1 = [1,2,3]
print(type(list1))
# np.array()를 사용해 리스트를 ndarray로 변환한다.
array1 = np.array(list1)
print(type(array1))
print(array1, array1.dtype)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# [1 2 3] int32

# %%
# 숫자와 문자열이 섞인 리스트는 하나의 공통 dtype으로 변환된다.
list2 = [1, 2, 'test']
array2 = np.array(list2)
print(array2, array2.dtype)

# 정수와 실수가 섞이면 더 넓은 표현 범위의 실수형으로 변환된다.
list3 = [1, 2, 3.0]
array3 = np.array(list3)
print(array3, array3.dtype)

# %%
# 정수형 배열을 생성한다.
array_int = np.array([1, 2, 3])
# astype('float64')로 정수형 배열을 실수형 배열로 변환한다.
array_float = array_int.astype('float64')
print(array_float, array_float.dtype)

# 다시 정수형으로 형변환해 dtype 변화를 확인한다.
array_int1= array_float.astype('int32')
print(array_int1, array_int1.dtype)

# 실수값 배열을 정수형으로 바꾸면 소수점 이하는 잘린다.
array_float1 = np.array([1.1, 2.1, 3.1])
array_int2= array_float1.astype('int32')
print(array_int2, array_int2.dtype)

# %% [markdown]
# ### ndarray를 편리하게 생성하기 - arange, zeros, ones

# %%
# arange()는 지정한 범위의 연속된 값을 갖는 ndarray를 생성한다.
sequence_array = np.arange(10)
print(sequence_array)
# 생성된 배열의 dtype과 shape 정보를 함께 확인한다.
print(sequence_array.dtype, sequence_array.shape)

# %%
# 모든 원소가 0인 3x2 배열을 정수형으로 생성한다.
zero_array = np.zeros((3,2),dtype='int32')
print(zero_array)
print(zero_array.dtype, zero_array.shape)

# 모든 원소가 1인 3x2 배열을 생성한다.
one_array = np.ones((3,2))
print(one_array)
print(one_array.dtype, one_array.shape)

# %% [markdown]
# ### reshape

# %%
# 0부터 9까지 1차원 배열을 생성한다.
array1 = np.arange(10)
print('array1:\n', array1)

# 1차원 배열을 2행 5열 구조로 재배열한다.
array2 = array1.reshape(2,5)
print('array2:\n',array2)

# 같은 데이터를 5행 2열 구조로도 재배열할 수 있다.
array3 = array1.reshape(5,2)
print('array3:\n',array3)

# %%
# 전체 원소 수가 맞지 않으면 reshape()는 ValueError를 발생시킨다.
array1.reshape(4,3)

# %%
# 0부터 9까지의 1차원 배열을 다시 생성한다.
array1 = np.arange(10)
print(array1)

# reshape(-1, 5)는 열 개수 5에 맞춰 행 개수를 자동 계산한다.
array2 = array1.reshape(-1,5)
print('array2 shape:',array2.shape)

# reshape(5, -1)는 행 개수 5에 맞춰 열 개수를 자동 계산한다.
array3 = array1.reshape(5,-1)
print('array3 shape:',array3.shape)

# %%
# -1을 사용해도 전체 원소 수가 맞지 않으면 reshape는 실패한다.
array1 = np.arange(10)
array4 = array1.reshape(-1,4)

# %%
# 0부터 7까지의 값을 갖는 1차원 배열을 만든다.
array1 = np.arange(8)
# 이를 2 x 2 x 2 구조의 3차원 배열로 변환한다.
array3d = array1.reshape((2,2,2))
print('array3d:\n',array3d.tolist())

# 3차원 ndarray를 2차원 ndarray(세로 벡터)로 변환한다.
array5 = array3d.reshape(-1,1)
print('array5:\n',array5.tolist())
print('array5 shape:',array5.shape)

# 1차원 ndarray도 같은 방식으로 2차원 열 벡터로 바꿀 수 있다.
array6 = array1.reshape(-1,1)
print('array6:\n',array6.tolist())
print('array6 shape:',array6.shape)

# %% [markdown]
# ### indexing

# %% [markdown]
# * 단일값 추출

# %%
# 1부터 9까지의 값을 갖는 1차원 ndarray를 생성한다.
array1 = np.arange(start=1, stop=10)
print('array1:',array1)
# 인덱스는 0부터 시작하므로 array1[2]는 세 번째 원소를 의미한다.
value = array1[2]
print('value:',value)
# 개별 원소를 꺼내면 넘파이 스칼라 타입이 반환된다.
print(type(value))

# %%
# 음수 인덱스를 사용하면 배열의 뒤쪽 원소를 쉽게 참조할 수 있다.
print('맨 뒤의 값:',array1[-1], ', 맨 뒤에서 두번째 값:',array1[-2])

# %%
# ndarray는 mutable 객체이므로 특정 인덱스의 값을 직접 변경할 수 있다.
array1[0] = 9
array1[8] = 0
print('array1:',array1)

# %%
# 1차원 배열을 만든 뒤 3x3 형태의 2차원 배열로 변환한다.
array1d = np.arange(start=1, stop=10)
array2d = array1d.reshape(3,3)
print(array2d)

# [행, 열] 형식의 인덱싱으로 원하는 위치의 값을 조회한다.
print('(row=0,col=0) index 가리키는 값:', array2d[0,0] )
print('(row=0,col=1) index 가리키는 값:', array2d[0,1] )
print('(row=1,col=0) index 가리키는 값:', array2d[1,0] )
print('(row=2,col=2) index 가리키는 값:', array2d[2,2] )

# %% [markdown]
# * Slicing

# %%
# 슬라이싱을 설명하기 위해 1차원 배열을 생성한다.
array1 = np.arange(start=1, stop=10)
# 0번부터 2번 인덱스까지, 즉 앞의 3개 원소를 잘라낸다.
array3 = array1[0:3]
print(array3)
print(type(array3))

# %%
# 다시 1차원 배열을 생성한다.
array1 = np.arange(start=1, stop=10)
# 시작 인덱스를 생략하면 처음부터 슬라이싱한다.
array4 = array1[:3]
print(array4)

# 끝 인덱스를 생략하면 지정한 위치부터 끝까지 슬라이싱한다.
array5 = array1[3:]
print(array5)

# 둘 다 생략하면 전체 배열이 반환된다.
array6 = array1[:]
print(array6)

# %%
# 1차원 배열을 3x3 2차원 배열로 변환한다.
array1d = np.arange(start=1, stop=10)
array2d = array1d.reshape(3,3)
print('array2d:\n',array2d)

# 행과 열 범위를 함께 지정해 부분 배열을 추출한다.
print('array2d[0:2, 0:2] \n', array2d[0:2, 0:2])
print('array2d[1:3, 0:3] \n', array2d[1:3, 0:3])
print('array2d[1:3, :] \n', array2d[1:3, :])
print('array2d[:, :] \n', array2d[:, :])
print('array2d[:2, 1:] \n', array2d[:2, 1:])
print('array2d[:2, 0] \n', array2d[:2, 0])

# %%
# 행 인덱스 하나만 지정하면 해당 행 전체가 1차원 배열로 반환된다.
print(array2d[0])
print(array2d[1])
print('array2d[0] shape:', array2d[0].shape, 'array2d[1] shape:', array2d[1].shape )

# %% [markdown]
# * fancy indexing

# %%
# fancy indexing 예제를 위해 3x3 배열을 준비한다.
array1d = np.arange(start=1, stop=10)
array2d = array1d.reshape(3,3)

# 여러 행 인덱스를 리스트로 전달해 특정 열의 값을 한 번에 조회한다.
array3 = array2d[[0,1], 2]
print('array2d[[0,1], 2] => ',array3.tolist())

# 여러 행과 열 범위를 조합해 부분 배열을 추출한다.
array4 = array2d[[0,1], 0:2]
print('array2d[[0,1], 0:2] => ',array4.tolist())

# 행 인덱스 리스트만 전달하면 선택한 행들만 새로운 배열로 반환된다.
array5 = array2d[[0,1]]
print('array2d[[0,1]] => ',array5.tolist())

# %% [markdown]
# * Boolean indexing

# %%
# 1차원 배열을 생성한다.
array1d = np.arange(start=1, stop=10)
# 조건식 array1d > 5가 True인 위치의 값만 선택한다.
array3 = array1d[array1d > 5]
print('array1d > 5 불린 인덱싱 결과 값 :', array3)

# %%
# 비교 연산의 결과는 원소별 True/False로 이루어진 불린 배열이다.
array1d > 5

# %%
# 직접 만든 불린 마스크를 사용해 원하는 위치의 값만 선택한다.
boolean_indexes = np.array([False, False, False, False, False,  True,  True,  True,  True])
array3 = array1d[boolean_indexes]
print('불린 인덱스로 필터링 결과 :', array3)

# %%
# 정수 인덱스 배열을 사용해 특정 위치의 값만 선택한다.
indexes = np.array([5,6,7,8])
array4 = array1d[ indexes ]
print('일반 인덱스로 필터링 결과 :',array4)

# %% [markdown]
# ### 행렬의 정렬 – sort( )와 argsort( )
#
# * 행렬 정렬

# %%
# 정렬 예제를 위해 1차원 원본 배열을 만든다.
org_array = np.array([ 3, 1, 9, 5]) 
print('원본 행렬:', org_array)
# np.sort()는 정렬된 새로운 배열을 반환하고 원본은 유지한다.
sort_array1 = np.sort(org_array)         
print ('np.sort( ) 호출 후 반환된 정렬 행렬:', sort_array1) 
print('np.sort( ) 호출 후 원본 행렬:', org_array)
# ndarray.sort()는 원본 배열 자체를 정렬하고 반환값은 None이다.
sort_array2 = org_array.sort()
print('org_array.sort( ) 호출 후 반환된 행렬:', sort_array2)
print('org_array.sort( ) 호출 후 원본 행렬:', org_array)

# %%
# [::-1] 슬라이싱을 이용해 오름차순 결과를 뒤집으면 내림차순 정렬이 된다.
sort_array1_desc = np.sort(org_array)[::-1]
print ('내림차순으로 정렬:', sort_array1_desc)

# %%
# 2차원 배열을 준비한다.
array2d = np.array([[8, 12], 
                   [7, 1 ]])

# axis=0은 같은 열끼리 비교해 행 방향으로 정렬한다.
sort_array2d_axis0 = np.sort(array2d, axis=0)
print('로우 방향으로 정렬:\n', sort_array2d_axis0)

# axis=1은 같은 행 안에서 열 방향으로 정렬한다.
sort_array2d_axis1 = np.sort(array2d, axis=1)
print('컬럼 방향으로 정렬:\n', sort_array2d_axis1)

# %% [markdown]
# * 정렬 행렬의 인덱스 반환

# %%
# argsort()는 값 자체가 아니라 정렬되었을 때의 원본 인덱스를 반환한다.
org_array = np.array([ 3, 1, 9, 5]) 
sort_indices = np.argsort(org_array)
print(type(sort_indices))
print('행렬 정렬 시 원본 행렬의 인덱스:', sort_indices)

# %%
# argsort() 결과를 뒤집으면 내림차순 정렬에 해당하는 인덱스를 얻을 수 있다.
org_array = np.array([ 3, 1, 9, 5]) 
sort_indices_desc = np.argsort(org_array)[::-1]
print('행렬 내림차순 정렬 시 원본 행렬의 인덱스:', sort_indices_desc)

# %%
# 이름 배열과 점수 배열을 나란히 준비한다.
import numpy as np

name_array = np.array(['John', 'Mike', 'Sarah', 'Kate', 'Samuel'])
score_array= np.array([78, 95, 84, 98, 88])

# 점수를 오름차순 정렬했을 때의 인덱스를 구한다.
sort_indices_asc = np.argsort(score_array)
print('성적 오름차순 정렬 시 score_array의 인덱스:', sort_indices_asc)
# 이 인덱스를 이름 배열에 적용하면 점수 순서대로 이름을 출력할 수 있다.
print('성적 오름차순으로 name_array의 이름 출력:', name_array[sort_indices_asc])

# %% [markdown]
# ### 선형대수 연산 – 행렬 내적과 전치 행렬 구하기
#
# * 행렬 내적

# %%
# 2x3 행렬 A를 생성한다.
A = np.array([[1, 2, 3],
              [4, 5, 6]])
# 3x2 행렬 B를 생성한다.
B = np.array([[7, 8],
              [9, 10],
              [11, 12]])

# np.dot()으로 두 행렬의 내적(행렬 곱)을 계산한다.
dot_product = np.dot(A, B)
print('행렬 내적 결과:\n', dot_product)

# %% [markdown]
# * 전치 행렬

# %%
# 2x2 행렬을 생성한다.
A = np.array([[1, 2],
              [3, 4]])
# np.transpose()로 행과 열을 서로 바꾼 전치 행렬을 구한다.
transpose_mat = np.transpose(A)
print('A의 전치 행렬:\n', transpose_mat)
