# %% [markdown]
# ## 앙상블 학습

# %% [markdown]
# 음성,이미지, 영상 등의 비정형 데이터의 분류는 딥러닝이 뛰어난 성능을 보이지만 대부분 정형 데이터 분류 시에는 앙상블이 뛰어난 성능을 나타냄.
# 부스팅: 여러 개의 분류기가 순차적으로 학습을 수행하되, 앞에서 학습한 분류기가 예측이 틀린 데이터에 대해서 올바르게 예측할 수 있도록 다음 분류기에는 가중치를 부여하면서 학습과 예측을 진행하는 것임.
#
# 보팅 유형
# - 하드보팅
# 다수의 분류기가 결정한 예측값을 최종 보팅 결괏값으로 선정하는 것임.
# - 소프트 보팅
# 분류기들의 레이블 값 결정 확률을 모두 더하고 이를 평균해서 이들 중 확률이 가장 높은 레이블 값을 최종 보팅 결괏값으로 선정함.
#
# 소프트 보팅이 더 많이 쓰임.

# %%
import pandas as pd

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

cancer = load_breast_cancer()

data_df = pd.DataFrame(cancer.data, columns=cancer.feature_names)
data_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33            184.6
# 1                 0.05667  ...         24.99          23.41            158.8
# 2                 0.05999  ...         23.57          25.53            152.5
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
#
# [3 rows x 30 columns]

# %%
# 개별 모델은 로지스틱 회귀와 KNN 임. 
lr_clf = LogisticRegression(solver='liblinear')
knn_clf = KNeighborsClassifier(n_neighbors=8)

# 개별 모델을 소프트 보팅 기반의 앙상블 모델로 구현한 분류기 
vo_clf = VotingClassifier( estimators=[('LR',lr_clf),('KNN',knn_clf)] , voting='soft' )

X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, 
                                                    test_size=0.2 , random_state= 156)

# VotingClassifier 학습/예측/평가. 
vo_clf.fit(X_train , y_train)
pred = vo_clf.predict(X_test)
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test , pred)))

# 개별 모델의 학습/예측/평가.
classifiers = [lr_clf, knn_clf]
for classifier in classifiers:
    classifier.fit(X_train , y_train)
    pred = classifier.predict(X_test)
    class_name= classifier.__class__.__name__
    print('{0} 정확도: {1:.4f}'.format(class_name, accuracy_score(y_test , pred)))
# Out:
# Voting 분류기 정확도: 0.9561
# LogisticRegression 정확도: 0.9474
# KNeighborsClassifier 정확도: 0.9386

# %% [markdown]
# ## 랜덤포레스트의 개요 및 실습

# %% [markdown]
# 배깅: 같은 알고리즘으로 여러 개의 분류기를 만들어서 보팅으로 최종 결정하는 알고리즘.
# 대표적인 방법으로는 랜덤 포레스트가 있음.
#
# BootStrapping 분할방식: 여러 개의 데이터 세트를
# 중첩되게 분리하는 것.

# %%
def get_new_feature_name_df(old_feature_name_df):
    feature_dup_df = pd.DataFrame(data=old_feature_name_df.groupby('column_name').cumcount(),
                                  columns=['dup_cnt'])
    feature_dup_df = feature_dup_df.reset_index()
    new_feature_name_df = pd.merge(old_feature_name_df.reset_index(), feature_dup_df, how='outer')
    new_feature_name_df['column_name'] = new_feature_name_df[['column_name', 'dup_cnt']].apply(lambda x : x[0]+'_'+str(x[1]) 
                                                                                         if x[1] >0 else x[0] ,  axis=1)
    new_feature_name_df = new_feature_name_df.drop(['index'], axis=1)
    return new_feature_name_df

# %%
import pandas as pd

def get_human_dataset( ):
    
    # 각 데이터 파일들은 공백으로 분리되어 있으므로 read_csv에서 공백 문자를 sep으로 할당.
    feature_name_df = pd.read_csv('./human_activity/features.txt',sep='\s+',
                        header=None,names=['column_index','column_name'])
    
    # 중복된 피처명을 수정하는 get_new_feature_name_df()를 이용, 신규 피처명 DataFrame생성. 
    new_feature_name_df = get_new_feature_name_df(feature_name_df)
    
    # DataFrame에 피처명을 컬럼으로 부여하기 위해 리스트 객체로 다시 변환
    feature_name = new_feature_name_df.iloc[:, 1].values.tolist()
    
    # 학습 피처 데이터 셋과 테스트 피처 데이터을 DataFrame으로 로딩. 컬럼명은 feature_name 적용
    X_train = pd.read_csv('./human_activity/train/X_train.txt',sep='\s+', names=feature_name )
    X_test = pd.read_csv('./human_activity/test/X_test.txt',sep='\s+', names=feature_name)
    
    # 학습 레이블과 테스트 레이블 데이터을 DataFrame으로 로딩하고 컬럼명은 action으로 부여
    y_train = pd.read_csv('./human_activity/train/y_train.txt',sep='\s+',header=None,names=['action'])
    y_test = pd.read_csv('./human_activity/test/y_test.txt',sep='\s+',header=None,names=['action'])
    
    # 로드된 학습/테스트용 DataFrame을 모두 반환 
    return X_train, X_test, y_train, y_test


X_train, X_test, y_train, y_test = get_human_dataset()
# Out:
# /var/folders/sm/h111486118b28hbn19xfh73r0000gn/T/ipykernel_25480/4103130684.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if x[1] >0 else x[0] ,  axis=1)
# /var/folders/sm/h111486118b28hbn19xfh73r0000gn/T/ipykernel_25480/4103130684.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_feature_name_df['column_name'] = new_feature_name_df[['column_name', 'dup_cnt']].apply(lambda x : x[0]+'_'+str(x[1])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# 결정 트리에서 사용한 get_human_dataset( )을 이용해 학습/테스트용 DataFrame 반환
X_train, X_test, y_train, y_test = get_human_dataset()

# 랜덤 포레스트 학습 및 별도의 테스트 셋으로 예측 성능 평가
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(X_test)
accuracy = accuracy_score(y_test , pred)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))
# Out:
# 랜덤 포레스트 정확도: 0.9223

# %% [markdown]
# 랜덤 포레스트 하이퍼 파리미터 및 튜닝
#
# 트리 기반의 앙상블 알고리즘의 단점은 하이퍼 파라미터가 너무 많고, 그로 인해 튜닝을 위한 시간이 많이 소모되는다는 정도.
#
# n_estimator: 결정 트리의 개수를 지정. 디폴트는 10개임. 많이 설정하면 좋은 성능 기대할 수는 있지만 무조건 향상되는 거는 아님
# max_features: 결정 트리에 사용된 max_feature 파라미터랑 같은거임. 트리를 전체 feature가 아니라 sqrt만큼 참조함.
# ..

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'n_estimators':[100],
    'max_depth' : [6, 8, 10, 12], 
    'min_samples_leaf' : [8, 12, 18 ],
    'min_samples_split' : [8, 16, 20]
}
# RandomForestClassifier 객체 생성 후 GridSearchCV 수행
rf_clf = RandomForestClassifier(random_state=0, n_jobs=-1)
grid_cv = GridSearchCV(rf_clf , param_grid=params , cv=2, n_jobs=-1 )
grid_cv.fit(X_train , y_train)

print('최적 하이퍼 파라미터:\n', grid_cv.best_params_)
print('최고 예측 정확도: {0:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:
#  {'max_depth': 10, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 100}
# 최고 예측 정확도: 0.9172

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'n_estimators':[100],
    'max_depth' : [6, 8, 10, 12], 
    'min_samples_leaf' : [8, 12, 18 ],
    'min_samples_split' : [8, 16, 20]
}
# RandomForestClassifier 객체 생성 후 GridSearchCV 수행
rf_clf = RandomForestClassifier(random_state=0, n_jobs=-1)
grid_cv = GridSearchCV(rf_clf , param_grid=params , cv=2, n_jobs=-1 )
grid_cv.fit(X_train , y_train)

print('최적 하이퍼 파라미터:\n', grid_cv.best_params_)
print('최고 예측 정확도: {0:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:
#  {'max_depth': 10, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 100}
# 최고 예측 정확도: 0.9172

# %%
rf_clf1 = RandomForestClassifier(n_estimators=300, max_depth=10, min_samples_leaf=8, \
                                 min_samples_split=8, random_state=0)
rf_clf1.fit(X_train , y_train)
pred = rf_clf1.predict(X_test)
print('예측 정확도: {0:.4f}'.format(accuracy_score(y_test , pred)))
# Out:
# 예측 정확도: 0.9162

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

ftr_importances_values = rf_clf1.feature_importances_
ftr_importances = pd.Series(ftr_importances_values,index=X_train.columns  )
ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature importances Top 20')
sns.barplot(x=ftr_top20 , y = ftr_top20.index)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('rf_feature_importances_top20.tif', format='tif', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## GBM (Gradient Boost Machine)

# %% [markdown]
# 부스팅 알고리즘은 여러개의 약한 학습기를 순차적으로 학습 - 예측 하면서 잘못 예측한 데이터에 가중치 부여를 통해 오류를 개선해 나가면서 학습하는 방식임
# 에이다 부스트: 오류 데이터에 가중치를 부여하면서 부스팅을 수행하는 대표적인 알고리즘
# GBM은 가중치 업데이트를 경사 하강법을 이용하는 것이 큰 차이이다. 오류값은 실제값 - 예측 값입. 분류와 회귀 둘 다 가능함

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
import time
import warnings
warnings.filterwarnings('ignore')

# 데이터 로드 (앞서 정의한 함수 사용)
X_train, X_test, y_train, y_test = get_human_dataset()

# GBM 수행 시간 측정을 위한 시작 시간 설정
start_time = time.time()

gb_clf = GradientBoostingClassifier(random_state=0)
gb_clf.fit(X_train, y_train)
gb_pred = gb_clf.predict(X_test)
gb_accuracy = accuracy_score(y_test, gb_pred)

print('GBM 정확도: {0:.4f}'.format(gb_accuracy))
print("GBM 수행 시간: {0:.1f} 초".format(time.time() - start_time))

# %% [markdown]
# GBM은 수행 시간이 오래 걸림. 성능은 괜찮지만 학습에 많은 시간이 필요하다는 점은 문제임.

# %% [markdown]
# ## XGBoost(eXtra Gradient Boost)

# %% [markdown]
# xgBoost는 트리 기반 앙상블 학습에서 가장 각광받고 있는 알고리즘 중 하나입니다.
# 분류에 있어서 다른 머신러닝 보다 뛰어난 예측 성능을 보임. xgBoost는 GBM에 기반하고 있지만, GBM의 느린 수행 시간 및 과적합 규제 부재 등의
# 문제를 해결해서 매우 각광을 받고 있음. 특히 XGBoost는 병렬 CPU환경에서 병렬 학습이 가능해 기존 GBM 보다 빠르게 학습을 완료할 수 있음.

# %%
import sys
print(sys.executable)

import xgboost
print("xgboost version:", xgboost.__version__)
# Out:
# /opt/anaconda3/bin/python
# xgboost version: 3.2.0

# %%
#Step1. 데이터 뽑아내기
import xgboost as xgb
from xgboost import plot_importance
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings

warnings.filterwarnings('ignore')

# 데이터 로드 (괄호 추가)
dataset = load_breast_cancer()
X_features = dataset.data
y_label = dataset.target

# DataFrame 생성 및 타겟 컬럼 추가
cancer_df = pd.DataFrame(data=X_features, columns=dataset.feature_names)
cancer_df['target'] = y_label

# 데이터 확인: hear -> head로 수정
cancer_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
#
# [3 rows x 31 columns]

# %%
#Step2. 레이블로 정리
print(dataset.target_names)
print(cancer_df['target'].value_counts())

# %%
#Step3. train/test 구분
#전체 데이터 중 80%는 학습용 데이터, 20%는 테스트용 데이터 추출
X_train, X_test, y_train, y_test = train_test_split(X_features, y_label, test_size=0.2, random_state=156)
#위에서 만든 거 90, 10 나눠서 분리
X_tr,X_val,y_tr,y_val=train_test_split(X_train,y_train,test_size=0.1,random_state=156)


print(X_train.shape, X_test.shape)
print(X_tr.shape,X_val.shape)

# %%
# 만약 구버전 XGBoost에서 DataFrame으로 DMatrix 생성이 안될 경우 X_train.values로 넘파이 변환.
# 학습, 검증, 테스트용 DMatrix를 생성.
dtr = xgb.DMatrix(data=X_tr, label=y_tr)
dval = xgb.DMatrix(data=X_val, label=y_val)
dtest = xgb.DMatrix(data=X_test , label=y_test)

# %%
params = { 'max_depth':3,
          'eta': 0.05,
          'objective':'binary:logistic',
          'eval_metric':'logloss'
         }
num_rounds = 400

# %%
# 학습 데이터 셋은 'train' 또는 평가 데이터 셋은 'eval' 로 명기합니다. 
eval_list = [(dtr,'train'),(dval,'eval')] # 또는 eval_list = [(dval,'eval')] 만 명기해도 무방. 

# 하이퍼 파라미터와 early stopping 파라미터를 train( ) 함수의 파라미터로 전달
xgb_model = xgb.train(params = params , dtrain=dtr , num_boost_round=num_rounds , \
                      early_stopping_rounds=50, evals=eval_list )

# %%
pred_probs = xgb_model.predict(dtest)
print('predict( ) 수행 결과값을 10개만 표시, 예측 확률 값으로 표시됨')
print(np.round(pred_probs[:10],3))

# 예측 확률이 0.5 보다 크면 1 , 그렇지 않으면 0 으로 예측값 결정하여 List 객체인 preds에 저장 
preds = [ 1 if x > 0.5 else 0 for x in pred_probs ]
print('예측값 10개만 표시:',preds[:10])

# %%
get_clf_eval(y_test, preds, pred_probs)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgb_model, ax=ax)
plt.savefig('p239_xgb_feature_importance.tif', format='tif', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 사이킷런 래퍼 XGBoost의 개요 및 적용

# %%
   # 사이킷런 래퍼 XGBoost 클래스인 XGBClassifier 임포트
from xgboost import XGBClassifier

#Warning 메시지를 없애기 위해 eval_metric 값을 XGBClassifier 생성 인자로 입력.
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3, eval_metric='logloss')
xgb_wrapper.fit(X_train, y_train, verbose=True)
w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

# %%
get_clf_eval(y_test , w_preds, w_pred_proba)

# %%
from xgboost import XGBClassifier

evals = [(X_test, y_test)]

xgb_wrapper = XGBClassifier(
    n_estimators=400,
    learning_rate=0.1,
    max_depth=3,
    early_stopping_rounds=100,
    eval_metric="logloss"
)

xgb_wrapper.fit(
    X_train, y_train,
    eval_set=evals,
    verbose=True
)

ws100_preds = xgb_wrapper.predict(X_test)
ws100_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

# %%
xgb_wrapper = XGBClassifier(
    n_estimators=400,
    learning_rate=0.1,
    max_depth=3,
    early_stopping_rounds=10,
    eval_metric="logloss"
)

evals = [(X_test, y_test)]

xgb_wrapper.fit(X_train, y_train, eval_set=evals, verbose=True)
get_clf_eval(y_test,ws10_preds,ws10_pred_proba)

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
# 사이킷런 래퍼 클래스를 입력해도 무방. 
plot_importance(xgb_wrapper, ax=ax)

# %% [markdown]
# ## LightGBM

# %% [markdown]
# xgBooot도 뛰어난 부스팅 알고리즘이지만 여전히 학습 시간이 오래 걸림
# lightGBM은 학습에 걸리는 시간이 훨씬 적음. 작은 데이터에 적용하면은 과적합 문제가 발생할 수 있기는 함. 1만건 이하의 데이터에는 사용하지 않는게좋음

# %%
import lightgbm

print(lightgbm.__version__)
# Out:
# 4.6.0

# %%
from lightgbm import LGBMClassifier, early_stopping, log_evaluation
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

dataset = load_breast_cancer()
cancer_df = pd.DataFrame(data=dataset.data, columns=dataset.feature_names)
cancer_df['target'] = dataset.target
X_features = cancer_df.iloc[:, :-1]
y_label = cancer_df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X_features, y_label, test_size=0.2, random_state=156)
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=156)

lgbm_wrapper = LGBMClassifier(n_estimators=400, learning_rate=0.05)

evals = [(X_tr, y_tr), (X_val, y_val)]
lgbm_wrapper.fit(
    X_tr, y_tr,
    eval_set=evals,
    eval_metric="logloss",
    callbacks=[early_stopping(50), log_evaluation(True)]  # early_stopping_rounds, verbose 대체
)

preds = lgbm_wrapper.predict(X_test)
pred_proba = lgbm_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 251, number of negative: 158
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000224 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4092
# [LightGBM] [Info] Number of data points in the train set: 409, number of used features: 30
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.613692 -> initscore=0.462858
# [LightGBM] [Info] Start training from score 0.462858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	training's binary_logloss: 0.625671	valid_1's binary_logloss: 0.628248
# Training until validation scores don't improve for 50 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	training's binary_logloss: 0.588173	valid_1's binary_logloss: 0.601106
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	training's binary_logloss: 0.554518	valid_1's binary_logloss: 0.577587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	training's binary_logloss: 0.523972	valid_1's binary_logloss: 0.556324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	training's binary_logloss: 0.49615	valid_1's binary_logloss: 0.537407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	training's binary_logloss: 0.470108	valid_1's binary_logloss: 0.519401
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	training's binary_logloss: 0.446647	valid_1's binary_logloss: 0.502637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	training's binary_logloss: 0.425055	valid_1's binary_logloss: 0.488311
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	training's binary_logloss: 0.405125	valid_1's binary_logloss: 0.474664
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	training's binary_logloss: 0.386526	valid_1's binary_logloss: 0.461267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	training's binary_logloss: 0.367027	valid_1's binary_logloss: 0.444274
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	training's binary_logloss: 0.350713	valid_1's binary_logloss: 0.432755
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	training's binary_logloss: 0.334601	valid_1's binary_logloss: 0.421371
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	training's binary_logloss: 0.319854	valid_1's binary_logloss: 0.411418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	training's binary_logloss: 0.306374	valid_1's binary_logloss: 0.402989
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	training's binary_logloss: 0.293116	valid_1's binary_logloss: 0.393973
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	training's binary_logloss: 0.280812	valid_1's binary_logloss: 0.384801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	training's binary_logloss: 0.268352	valid_1's binary_logloss: 0.376191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	training's binary_logloss: 0.256942	valid_1's binary_logloss: 0.368378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	training's binary_logloss: 0.246443	valid_1's binary_logloss: 0.362062
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	training's binary_logloss: 0.236874	valid_1's binary_logloss: 0.355162
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	training's binary_logloss: 0.227501	valid_1's binary_logloss: 0.348933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	training's binary_logloss: 0.218988	valid_1's binary_logloss: 0.342819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	training's binary_logloss: 0.210621	valid_1's binary_logloss: 0.337386
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	training's binary_logloss: 0.202076	valid_1's binary_logloss: 0.331523
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	training's binary_logloss: 0.194199	valid_1's binary_logloss: 0.326349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	training's binary_logloss: 0.187107	valid_1's binary_logloss: 0.322785
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	training's binary_logloss: 0.180535	valid_1's binary_logloss: 0.317877
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	training's binary_logloss: 0.173834	valid_1's binary_logloss: 0.313928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	training's binary_logloss: 0.167198	valid_1's binary_logloss: 0.310105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	training's binary_logloss: 0.161229	valid_1's binary_logloss: 0.307107
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	training's binary_logloss: 0.155494	valid_1's binary_logloss: 0.303837
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	training's binary_logloss: 0.149125	valid_1's binary_logloss: 0.300315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	training's binary_logloss: 0.144045	valid_1's binary_logloss: 0.297816
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	training's binary_logloss: 0.139341	valid_1's binary_logloss: 0.295387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	training's binary_logloss: 0.134625	valid_1's binary_logloss: 0.293063
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	training's binary_logloss: 0.129167	valid_1's binary_logloss: 0.289127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	training's binary_logloss: 0.12472	valid_1's binary_logloss: 0.288697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	training's binary_logloss: 0.11974	valid_1's binary_logloss: 0.28576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	training's binary_logloss: 0.115054	valid_1's binary_logloss: 0.282853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	training's binary_logloss: 0.110662	valid_1's binary_logloss: 0.279441
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	training's binary_logloss: 0.106358	valid_1's binary_logloss: 0.28113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	training's binary_logloss: 0.102324	valid_1's binary_logloss: 0.279139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	training's binary_logloss: 0.0985699	valid_1's binary_logloss: 0.276465
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	training's binary_logloss: 0.094858	valid_1's binary_logloss: 0.275946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	training's binary_logloss: 0.0912486	valid_1's binary_logloss: 0.272819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	training's binary_logloss: 0.0883115	valid_1's binary_logloss: 0.272306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	training's binary_logloss: 0.0849963	valid_1's binary_logloss: 0.270452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	training's binary_logloss: 0.0821742	valid_1's binary_logloss: 0.268671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	training's binary_logloss: 0.0789991	valid_1's binary_logloss: 0.267587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	training's binary_logloss: 0.0761072	valid_1's binary_logloss: 0.26626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	training's binary_logloss: 0.0732567	valid_1's binary_logloss: 0.265542
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	training's binary_logloss: 0.0706388	valid_1's binary_logloss: 0.264547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	training's binary_logloss: 0.0683911	valid_1's binary_logloss: 0.26502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	training's binary_logloss: 0.0659347	valid_1's binary_logloss: 0.264388
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	training's binary_logloss: 0.0636873	valid_1's binary_logloss: 0.263128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	training's binary_logloss: 0.0613354	valid_1's binary_logloss: 0.26231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	training's binary_logloss: 0.0591944	valid_1's binary_logloss: 0.262011
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	training's binary_logloss: 0.057033	valid_1's binary_logloss: 0.261454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	training's binary_logloss: 0.0550801	valid_1's binary_logloss: 0.260746
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	training's binary_logloss: 0.0532381	valid_1's binary_logloss: 0.260236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	training's binary_logloss: 0.0514074	valid_1's binary_logloss: 0.261586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	training's binary_logloss: 0.0494837	valid_1's binary_logloss: 0.261797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	training's binary_logloss: 0.0477826	valid_1's binary_logloss: 0.262533
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	training's binary_logloss: 0.0460364	valid_1's binary_logloss: 0.263305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	training's binary_logloss: 0.0444552	valid_1's binary_logloss: 0.264072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	training's binary_logloss: 0.0427638	valid_1's binary_logloss: 0.266223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	training's binary_logloss: 0.0412449	valid_1's binary_logloss: 0.266817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	training's binary_logloss: 0.0398589	valid_1's binary_logloss: 0.267819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	training's binary_logloss: 0.0383095	valid_1's binary_logloss: 0.267484
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	training's binary_logloss: 0.0368803	valid_1's binary_logloss: 0.270233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	training's binary_logloss: 0.0355637	valid_1's binary_logloss: 0.268442
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	training's binary_logloss: 0.0341747	valid_1's binary_logloss: 0.26895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	training's binary_logloss: 0.0328302	valid_1's binary_logloss: 0.266958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	training's binary_logloss: 0.0317853	valid_1's binary_logloss: 0.268091
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	training's binary_logloss: 0.0305626	valid_1's binary_logloss: 0.266419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	training's binary_logloss: 0.0295001	valid_1's binary_logloss: 0.268588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	training's binary_logloss: 0.0284699	valid_1's binary_logloss: 0.270964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	training's binary_logloss: 0.0273953	valid_1's binary_logloss: 0.270293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	training's binary_logloss: 0.0264668	valid_1's binary_logloss: 0.270523
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	training's binary_logloss: 0.0254636	valid_1's binary_logloss: 0.270683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	training's binary_logloss: 0.0245911	valid_1's binary_logloss: 0.273187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	training's binary_logloss: 0.0236486	valid_1's binary_logloss: 0.275994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	training's binary_logloss: 0.0228047	valid_1's binary_logloss: 0.274053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	training's binary_logloss: 0.0221693	valid_1's binary_logloss: 0.273211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	training's binary_logloss: 0.0213043	valid_1's binary_logloss: 0.272626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	training's binary_logloss: 0.0203934	valid_1's binary_logloss: 0.27534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	training's binary_logloss: 0.0195552	valid_1's binary_logloss: 0.276228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	training's binary_logloss: 0.0188623	valid_1's binary_logloss: 0.27525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	training's binary_logloss: 0.0183664	valid_1's binary_logloss: 0.276485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	training's binary_logloss: 0.0176788	valid_1's binary_logloss: 0.277052
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	training's binary_logloss: 0.0170059	valid_1's binary_logloss: 0.277686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	training's binary_logloss: 0.0164317	valid_1's binary_logloss: 0.275332
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	training's binary_logloss: 0.015878	valid_1's binary_logloss: 0.276236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	training's binary_logloss: 0.0152959	valid_1's binary_logloss: 0.274538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	training's binary_logloss: 0.0147216	valid_1's binary_logloss: 0.275244
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	training's binary_logloss: 0.0141758	valid_1's binary_logloss: 0.275829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	training's binary_logloss: 0.0136551	valid_1's binary_logloss: 0.276654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	training's binary_logloss: 0.0131585	valid_1's binary_logloss: 0.277859
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	training's binary_logloss: 0.0126961	valid_1's binary_logloss: 0.279265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	training's binary_logloss: 0.0122421	valid_1's binary_logloss: 0.276695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	training's binary_logloss: 0.0118067	valid_1's binary_logloss: 0.278488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	training's binary_logloss: 0.0113994	valid_1's binary_logloss: 0.278932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	training's binary_logloss: 0.0109799	valid_1's binary_logloss: 0.280997
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	training's binary_logloss: 0.0105953	valid_1's binary_logloss: 0.281454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	training's binary_logloss: 0.0102381	valid_1's binary_logloss: 0.282058
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	training's binary_logloss: 0.00986714	valid_1's binary_logloss: 0.279275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	training's binary_logloss: 0.00950998	valid_1's binary_logloss: 0.281427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	training's binary_logloss: 0.00915965	valid_1's binary_logloss: 0.280752
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	training's binary_logloss: 0.00882581	valid_1's binary_logloss: 0.282152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	training's binary_logloss: 0.00850714	valid_1's binary_logloss: 0.280894
# Early stopping, best iteration is:
# [61]	training's binary_logloss: 0.0532381	valid_1's binary_logloss: 0.260236

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가 
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    
get_clf_eval(y_test, preds, pred_proba)
# Out:
# 오차 행렬
# [[34  3]
#  [ 2 75]]
# 정확도: 0.9561, 정밀도: 0.9615, 재현율: 0.9740,    F1: 0.9677, AUC:0.9877

# %%
# plot_importance( )를 이용하여 feature 중요도 시각화
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgbm_wrapper, ax=ax)
plt.savefig('lightgbm_feature_importance.tif', format='tif', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 베이지안 최적화 기반의 HyperOpt를 이용한 하이퍼 파라미터 튜닝

# %% [markdown]
# ## 베이지안 최저과 기반의 HyperOpt를 이용한 하이퍼 파리미터 튜닝

# %% [markdown]
# ## 베이지안 최적화 기반의 HyperOpt를 이용한 파라미터 튜닝

# %%
pip install hyperopt
# Out:
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from hyperopt) (2.3.5)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.13/site-packages (from hyperopt) (1.16.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.13/site-packages (from hyperopt) (1.17.0)
# Requirement already satisfied: networkx>=2.2 in /opt/anaconda3/lib/python3.13/site-packages (from hyperopt) (3.5)
# Collecting future (from hyperopt)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from hyperopt) (4.67.1)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/lib/python3.13/site-packages (from hyperopt) (3.1.1)
# Collecting py4j (from hyperopt)
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.9 MB/s  0:00:00 eta 0:00:01
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# Installing collected packages: py4j, future, hyperopt
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [hyperopt]1/3 [future]
# Successfully installed future-1.0.0 hyperopt-0.2.7 py4j-0.10.9.9
# Note: you may need to restart the kernel to use updated packages.

# %%
from hyperopt import hp

# -10 ~ 10 사이의 1 간격을 가지는 입력 변수 x와 -15 ~ 15 사이의 1 간격을 가지는 입력 변수 y를 설정.
search_space = {'x': hp.quniform('x', -10, 10, 1),'y': hp.quniform('y', -15, 15, 1)}
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
from hyperopt import STATUS_OK

# 목적 함수를 생성. 변숫값과 변수 검색 공간을 가지는 딕셔너리를 인자로 받고, 특정 값을 반환
def objective_func(search_space):
    x = search_space['x']
    y = search_space['y']
    retval = x**2 - 20*y
    
    return retval

# %%
from hyperopt import fmin, tpe, Trials
import numpy as np

# 입력 결괏값을 저장한 Trials 객체값 생성.
trial_val = Trials()

# 목적 함수의 최솟값을 반환하는 최적 입력 변숫값을 5번의 입력값 시도(max_evals=5)로 찾아냄.
best_01 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=5
               , trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_01)
# Out:
# 100%|█████████████████████| 5/5 [00:00<00:00, 1900.28trial/s, best loss: -224.0]
# best: {'x': np.float64(-4.0), 'y': np.float64(12.0)}

# %%
trial_val = Trials()

# max_evals를 20회로 늘려서 재테스트
best_02 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=20
               , trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_02)
# Out:
# 100%|███████████████████| 20/20 [00:00<00:00, 1524.37trial/s, best loss: -296.0]
# best: {'x': np.float64(2.0), 'y': np.float64(15.0)}

# %%
# Trials 객체의 vals 속성에 {'입력변수명':개별 수행 시마다 입력된 값 리스트} 형태로 저장됨.
print(trial_val.vals)
# Out:
# {'x': [np.float64(-6.0), np.float64(-4.0), np.float64(4.0), np.float64(-4.0), np.float64(9.0), np.float64(2.0), np.float64(10.0), np.float64(-9.0), np.float64(-8.0), np.float64(-0.0), np.float64(-0.0), np.float64(1.0), np.float64(9.0), np.float64(6.0), np.float64(9.0), np.float64(2.0), np.float64(-2.0), np.float64(-4.0), np.float64(7.0), np.float64(-0.0)], 'y': [np.float64(5.0), np.float64(10.0), np.float64(-2.0), np.float64(12.0), np.float64(1.0), np.float64(15.0), np.float64(7.0), np.float64(-10.0), np.float64(0.0), np.float64(-5.0), np.float64(-3.0), np.float64(2.0), np.float64(4.0), np.float64(10.0), np.float64(3.0), np.float64(3.0), np.float64(-14.0), np.float64(-8.0), np.float64(11.0), np.float64(-0.0)]}

# %%
import pandas as pd

# results에서 loss 키값에 해당하는 밸류들을 추출하여 list로 생성. 
losses = [loss_dict['loss'] for loss_dict in trial_val.results]

# DataFrame으로 생성.
result_df = pd.DataFrame({'x': trial_val.vals['x'], 'y': trial_val.vals['y'], 'losses': losses})
result_df
# Out:
#        x     y  losses
# 0   -6.0   5.0   -64.0
# 1   -4.0  10.0  -184.0
# 2    4.0  -2.0    56.0
# 3   -4.0  12.0  -224.0
# 4    9.0   1.0    61.0
# 5    2.0  15.0  -296.0
# 6   10.0   7.0   -40.0
# 7   -9.0 -10.0   281.0
# 8   -8.0   0.0    64.0
# 9   -0.0  -5.0   100.0
# 10  -0.0  -3.0    60.0
# 11   1.0   2.0   -39.0
# 12   9.0   4.0     1.0
# 13   6.0  10.0  -164.0
# 14   9.0   3.0    21.0
# 15   2.0   3.0   -56.0
# 16  -2.0 -14.0   284.0
# 17  -4.0  -8.0   176.0
# 18   7.0  11.0  -171.0
# 19  -0.0  -0.0     0.0

# %% [markdown]
# ## HyperOpt를 이용한 XGBoost 하이러 파라미터 최적화

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

dataset = load_breast_cancer()

cancer_df = pd.DataFrame(data=dataset.data, columns=dataset.feature_names)
cancer_df['target']= dataset.target
X_features = cancer_df.iloc[:, :-1]
y_label = cancer_df.iloc[:, -1]

# %%
# 전체 데이터 중 80%는 학습용 데이터, 20%는 테스트용 데이터 추출
X_train, X_test, y_train, y_test=train_test_split(X_features, y_label, test_size=0.2, random_state=156 )

# 앞에서 추출한 학습 데이터를 다시 학습과 검증 데이터로 분리
X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=156 )

# %%
from hyperopt import hp

# max_depth는 5에서 20까지 1간격으로, min_child_weight는 1에서 2까지 1간격으로
# colsample_bytree는 0.5에서 1사이, learning_rate는 0.01에서 0.2 사이 정규 분포된 값으로 검색.
xgb_search_space = {'max_depth': hp.quniform('max_depth', 5, 20, 1), 
                    'min_child_weight': hp.quniform('min_child_weight', 1, 2, 1),
                    'learning_rate': hp.uniform('learning_rate', 0.01, 0.2),
                    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1),
                   }

# %%
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from hyperopt import STATUS_OK

# fmin()에서 입력된 search_space 값으로 입력된 모든 값은 실수형임.
# XGBClassifier의 정수형 하이퍼 파라미터는 정수형 변환을 해줘야 함.
# 정확도는 높을수록 더 좋은 수치임. -1 * 정확도를 곱해서 큰 정확도 값일수록 최소가 되도록 변환
def objective_func(search_space):
    # 수행 시간 절약을 위해 nestimators는 100으로 축소
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                            min_child_weight=int(search_space['min_child_weight']),
                            learning_rate=search_space['learning_rate'],
                            colsample_bytree=search_space['colsample_bytree'],
                            eval_metric='logloss')
    accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=3)
    
    # accuracy는 cv=3 개수만큼 roc-auc 결과를 리스트로 가짐. 이를 평균해서 반환하되 -1을 곱함.
    return {'loss':-1 * np.mean(accuracy), 'status': STATUS_OK}

# %%
from hyperopt import fmin, tpe, Trials

trial_val = Trials()
best = fmin(fn=objective_func,
            space=xgb_search_space,
            algo=tpe.suggest,
            max_evals=50, # 최대 반복 횟수를 지정합니다.
            trials=trial_val, rstate=np.random.default_rng(seed=9))
print('best:', best)
# Out:
# 100%|████████| 50/50 [00:10<00:00,  4.89trial/s, best loss: -0.9670616939700244]
# best: {'colsample_bytree': np.float64(0.669163185162111), 'learning_rate': np.float64(0.14385430809747882), 'max_depth': np.float64(13.0), 'min_child_weight': np.float64(2.0)}

# %%
print('colsample_bytree:{0}, learning_rate:{1}, max_depth:{2}, min_child_weight:{3}'.format(
    round(best['colsample_bytree'], 5), round(best['learning_rate'], 5),
    int(best['max_depth']), int(best['min_child_weight'])))
# Out:
# colsample_bytree:0.66916, learning_rate:0.14385, max_depth:13, min_child_weight:2

# %%
xgb_wrapper = XGBClassifier(
    n_estimators=400,
    learning_rate=round(best['learning_rate'], 5),
    max_depth=int(best['max_depth']),
    min_child_weight=int(best['min_child_weight']),
    colsample_bytree=round(best['colsample_bytree'], 5),
    early_stopping_rounds=50,
    eval_metric='logloss'
)

evals = [(X_tr, y_tr), (X_val, y_val)]

xgb_wrapper.fit(
    X_tr,
    y_tr,
    eval_set=evals,
    verbose=True
)

preds = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [0]	validation_0-logloss:0.55465	validation_1-logloss:0.57366
# [1]	validation_0-logloss:0.46984	validation_1-logloss:0.52028
# [2]	validation_0-logloss:0.40249	validation_1-logloss:0.47239
# [3]	validation_0-logloss:0.34802	validation_1-logloss:0.43341
# [4]	validation_0-logloss:0.30250	validation_1-logloss:0.39696
# [5]	validation_0-logloss:0.26589	validation_1-logloss:0.37275
# [6]	validation_0-logloss:0.23529	validation_1-logloss:0.35516
# [7]	validation_0-logloss:0.20796	validation_1-logloss:0.33413
# [8]	validation_0-logloss:0.18672	validation_1-logloss:0.31805
# [9]	validation_0-logloss:0.16713	validation_1-logloss:0.30260
# [10]	validation_0-logloss:0.15125	validation_1-logloss:0.29824
# [11]	validation_0-logloss:0.13668	validation_1-logloss:0.29033
# [12]	validation_0-logloss:0.12485	validation_1-logloss:0.28472
# [13]	validation_0-logloss:0.11412	validation_1-logloss:0.27652
# [14]	validation_0-logloss:0.10497	validation_1-logloss:0.27322
# [15]	validation_0-logloss:0.09781	validation_1-logloss:0.26859
# [16]	validation_0-logloss:0.09024	validation_1-logloss:0.26540
# [17]	validation_0-logloss:0.08418	validation_1-logloss:0.26123
# [18]	validation_0-logloss:0.07902	validation_1-logloss:0.25627
# [19]	validation_0-logloss:0.07302	validation_1-logloss:0.25441
# [20]	validation_0-logloss:0.06784	validation_1-logloss:0.25412
# [21]	validation_0-logloss:0.06422	validation_1-logloss:0.25481
# [22]	validation_0-logloss:0.06020	validation_1-logloss:0.25279
# [23]	validation_0-logloss:0.05690	validation_1-logloss:0.25351
# [24]	validation_0-logloss:0.05327	validation_1-logloss:0.25340
# [25]	validation_0-logloss:0.05012	validation_1-logloss:0.25215
# [26]	validation_0-logloss:0.04769	validation_1-logloss:0.25231
# [27]	validation_0-logloss:0.04516	validation_1-logloss:0.24903
# [28]	validation_0-logloss:0.04289	validation_1-logloss:0.24995
# [29]	validation_0-logloss:0.04118	validation_1-logloss:0.25045
# [30]	validation_0-logloss:0.03969	validation_1-logloss:0.25126
# [31]	validation_0-logloss:0.03810	validation_1-logloss:0.24937
# [32]	validation_0-logloss:0.03666	validation_1-logloss:0.25264
# [33]	validation_0-logloss:0.03542	validation_1-logloss:0.25146
# [34]	validation_0-logloss:0.03422	validation_1-logloss:0.25198
# [35]	validation_0-logloss:0.03274	validation_1-logloss:0.25112
# [36]	validation_0-logloss:0.03172	validation_1-logloss:0.24703
# [37]	validation_0-logloss:0.03096	validation_1-logloss:0.24581
# [38]	validation_0-logloss:0.03016	validation_1-logloss:0.24475
# [39]	validation_0-logloss:0.02956	validation_1-logloss:0.24566
# [40]	validation_0-logloss:0.02889	validation_1-logloss:0.24281
# [41]	validation_0-logloss:0.02828	validation_1-logloss:0.24296
# [42]	validation_0-logloss:0.02753	validation_1-logloss:0.23884
# [43]	validation_0-logloss:0.02708	validation_1-logloss:0.24056
# [44]	validation_0-logloss:0.02653	validation_1-logloss:0.23893
# [45]	validation_0-logloss:0.02625	validation_1-logloss:0.23849
# [46]	validation_0-logloss:0.02576	validation_1-logloss:0.23947
# [47]	validation_0-logloss:0.02522	validation_1-logloss:0.23981
# [48]	validation_0-logloss:0.02497	validation_1-logloss:0.23828
# [49]	validation_0-logloss:0.02457	validation_1-logloss:0.23916
# [50]	validation_0-logloss:0.02435	validation_1-logloss:0.23903
# [51]	validation_0-logloss:0.02396	validation_1-logloss:0.23768
# [52]	validation_0-logloss:0.02340	validation_1-logloss:0.23398
# [53]	validation_0-logloss:0.02322	validation_1-logloss:0.23363
# [54]	validation_0-logloss:0.02303	validation_1-logloss:0.23542
# [55]	validation_0-logloss:0.02284	validation_1-logloss:0.23411
# [56]	validation_0-logloss:0.02267	validation_1-logloss:0.23580
# [57]	validation_0-logloss:0.02230	validation_1-logloss:0.23667
# [58]	validation_0-logloss:0.02215	validation_1-logloss:0.23640
# [59]	validation_0-logloss:0.02199	validation_1-logloss:0.23630
# [60]	validation_0-logloss:0.02175	validation_1-logloss:0.23514
# [61]	validation_0-logloss:0.02159	validation_1-logloss:0.23681
# [62]	validation_0-logloss:0.02143	validation_1-logloss:0.23559
# [63]	validation_0-logloss:0.02129	validation_1-logloss:0.23552
# [64]	validation_0-logloss:0.02115	validation_1-logloss:0.23715
# [65]	validation_0-logloss:0.02101	validation_1-logloss:0.23603
# [66]	validation_0-logloss:0.02063	validation_1-logloss:0.23291
# [67]	validation_0-logloss:0.02050	validation_1-logloss:0.23067
# [68]	validation_0-logloss:0.02039	validation_1-logloss:0.23120
# [69]	validation_0-logloss:0.02026	validation_1-logloss:0.23279
# [70]	validation_0-logloss:0.02014	validation_1-logloss:0.23274
# [71]	validation_0-logloss:0.02002	validation_1-logloss:0.23169
# [72]	validation_0-logloss:0.01990	validation_1-logloss:0.23324
# [73]	validation_0-logloss:0.01978	validation_1-logloss:0.23293
# [74]	validation_0-logloss:0.01967	validation_1-logloss:0.23193
# [75]	validation_0-logloss:0.01955	validation_1-logloss:0.22983
# [76]	validation_0-logloss:0.01944	validation_1-logloss:0.23136
# [77]	validation_0-logloss:0.01934	validation_1-logloss:0.23110
# [78]	validation_0-logloss:0.01925	validation_1-logloss:0.22920
# [79]	validation_0-logloss:0.01915	validation_1-logloss:0.22825
# [80]	validation_0-logloss:0.01904	validation_1-logloss:0.22976
# [81]	validation_0-logloss:0.01894	validation_1-logloss:0.22970
# [82]	validation_0-logloss:0.01885	validation_1-logloss:0.23112
# [83]	validation_0-logloss:0.01876	validation_1-logloss:0.23021
# [84]	validation_0-logloss:0.01867	validation_1-logloss:0.22997
# [85]	validation_0-logloss:0.01859	validation_1-logloss:0.22792
# [86]	validation_0-logloss:0.01850	validation_1-logloss:0.22882
# [87]	validation_0-logloss:0.01842	validation_1-logloss:0.22705
# [88]	validation_0-logloss:0.01835	validation_1-logloss:0.22790
# [89]	validation_0-logloss:0.01827	validation_1-logloss:0.22784
# [90]	validation_0-logloss:0.01818	validation_1-logloss:0.22683
# [91]	validation_0-logloss:0.01810	validation_1-logloss:0.22483
# [92]	validation_0-logloss:0.01801	validation_1-logloss:0.22627
# [93]	validation_0-logloss:0.01793	validation_1-logloss:0.22621
# [94]	validation_0-logloss:0.01786	validation_1-logloss:0.22435
# [95]	validation_0-logloss:0.01779	validation_1-logloss:0.22521
# [96]	validation_0-logloss:0.01772	validation_1-logloss:0.22440
# [97]	validation_0-logloss:0.01765	validation_1-logloss:0.22479
# [98]	validation_0-logloss:0.01758	validation_1-logloss:0.22392
# [99]	validation_0-logloss:0.01750	validation_1-logloss:0.22367
# [100]	validation_0-logloss:0.01744	validation_1-logloss:0.22193
# [101]	validation_0-logloss:0.01737	validation_1-logloss:0.22274
# [102]	validation_0-logloss:0.01731	validation_1-logloss:0.22193
# [103]	validation_0-logloss:0.01724	validation_1-logloss:0.22189
# [104]	validation_0-logloss:0.01718	validation_1-logloss:0.22269
# [105]	validation_0-logloss:0.01712	validation_1-logloss:0.22093
# [106]	validation_0-logloss:0.01705	validation_1-logloss:0.22088
# [107]	validation_0-logloss:0.01699	validation_1-logloss:0.22238
# [108]	validation_0-logloss:0.01693	validation_1-logloss:0.22240
# [109]	validation_0-logloss:0.01687	validation_1-logloss:0.22297
# [110]	validation_0-logloss:0.01681	validation_1-logloss:0.22223
# [111]	validation_0-logloss:0.01675	validation_1-logloss:0.22197
# [112]	validation_0-logloss:0.01669	validation_1-logloss:0.22029
# [113]	validation_0-logloss:0.01663	validation_1-logloss:0.22025
# [114]	validation_0-logloss:0.01657	validation_1-logloss:0.22022
# [115]	validation_0-logloss:0.01652	validation_1-logloss:0.22081
# [116]	validation_0-logloss:0.01646	validation_1-logloss:0.21915
# [117]	validation_0-logloss:0.01640	validation_1-logloss:0.21860
# [118]	validation_0-logloss:0.01635	validation_1-logloss:0.21837
# [119]	validation_0-logloss:0.01629	validation_1-logloss:0.21771
# [120]	validation_0-logloss:0.01624	validation_1-logloss:0.21917
# [121]	validation_0-logloss:0.01619	validation_1-logloss:0.21914
# [122]	validation_0-logloss:0.01613	validation_1-logloss:0.21974
# [123]	validation_0-logloss:0.01609	validation_1-logloss:0.21922
# [124]	validation_0-logloss:0.01603	validation_1-logloss:0.21764
# [125]	validation_0-logloss:0.01598	validation_1-logloss:0.21762
# [126]	validation_0-logloss:0.01593	validation_1-logloss:0.21741
# [127]	validation_0-logloss:0.01588	validation_1-logloss:0.21590
# [128]	validation_0-logloss:0.01584	validation_1-logloss:0.21456
# [129]	validation_0-logloss:0.01579	validation_1-logloss:0.21604
# [130]	validation_0-logloss:0.01573	validation_1-logloss:0.21605
# [131]	validation_0-logloss:0.01569	validation_1-logloss:0.21667
# [132]	validation_0-logloss:0.01564	validation_1-logloss:0.21607
# [133]	validation_0-logloss:0.01559	validation_1-logloss:0.21576
# [134]	validation_0-logloss:0.01554	validation_1-logloss:0.21710
# [135]	validation_0-logloss:0.01550	validation_1-logloss:0.21714
# [136]	validation_0-logloss:0.01545	validation_1-logloss:0.21742
# [137]	validation_0-logloss:0.01541	validation_1-logloss:0.21601
# [138]	validation_0-logloss:0.01536	validation_1-logloss:0.21598
# [139]	validation_0-logloss:0.01532	validation_1-logloss:0.21730
# [140]	validation_0-logloss:0.01528	validation_1-logloss:0.21674
# [141]	validation_0-logloss:0.01524	validation_1-logloss:0.21645
# [142]	validation_0-logloss:0.01519	validation_1-logloss:0.21707
# [143]	validation_0-logloss:0.01515	validation_1-logloss:0.21702
# [144]	validation_0-logloss:0.01511	validation_1-logloss:0.21706
# [145]	validation_0-logloss:0.01506	validation_1-logloss:0.21568
# [146]	validation_0-logloss:0.01502	validation_1-logloss:0.21627
# [147]	validation_0-logloss:0.01498	validation_1-logloss:0.21573
# [148]	validation_0-logloss:0.01495	validation_1-logloss:0.21695
# [149]	validation_0-logloss:0.01491	validation_1-logloss:0.21665
# [150]	validation_0-logloss:0.01487	validation_1-logloss:0.21672
# [151]	validation_0-logloss:0.01482	validation_1-logloss:0.21540
# [152]	validation_0-logloss:0.01479	validation_1-logloss:0.21566
# [153]	validation_0-logloss:0.01475	validation_1-logloss:0.21517
# [154]	validation_0-logloss:0.01471	validation_1-logloss:0.21524
# [155]	validation_0-logloss:0.01468	validation_1-logloss:0.21495
# [156]	validation_0-logloss:0.01464	validation_1-logloss:0.21618
# [157]	validation_0-logloss:0.01460	validation_1-logloss:0.21570
# [158]	validation_0-logloss:0.01457	validation_1-logloss:0.21631
# [159]	validation_0-logloss:0.01453	validation_1-logloss:0.21583
# [160]	validation_0-logloss:0.01450	validation_1-logloss:0.21542
# [161]	validation_0-logloss:0.01446	validation_1-logloss:0.21551
# [162]	validation_0-logloss:0.01443	validation_1-logloss:0.21434
# [163]	validation_0-logloss:0.01439	validation_1-logloss:0.21404
# [164]	validation_0-logloss:0.01436	validation_1-logloss:0.21465
# [165]	validation_0-logloss:0.01433	validation_1-logloss:0.21476
# [166]	validation_0-logloss:0.01429	validation_1-logloss:0.21431
# [167]	validation_0-logloss:0.01426	validation_1-logloss:0.21320
# [168]	validation_0-logloss:0.01423	validation_1-logloss:0.21436
# [169]	validation_0-logloss:0.01420	validation_1-logloss:0.21461
# [170]	validation_0-logloss:0.01417	validation_1-logloss:0.21419
# [171]	validation_0-logloss:0.01414	validation_1-logloss:0.21430
# [172]	validation_0-logloss:0.01410	validation_1-logloss:0.21399
# [173]	validation_0-logloss:0.01408	validation_1-logloss:0.21459
# [174]	validation_0-logloss:0.01405	validation_1-logloss:0.21567
# [175]	validation_0-logloss:0.01402	validation_1-logloss:0.21538
# [176]	validation_0-logloss:0.01399	validation_1-logloss:0.21496
# [177]	validation_0-logloss:0.01396	validation_1-logloss:0.21456
# [178]	validation_0-logloss:0.01393	validation_1-logloss:0.21468
# [179]	validation_0-logloss:0.01390	validation_1-logloss:0.21441
# [180]	validation_0-logloss:0.01387	validation_1-logloss:0.21465
# [181]	validation_0-logloss:0.01385	validation_1-logloss:0.21572
# [182]	validation_0-logloss:0.01382	validation_1-logloss:0.21584
# [183]	validation_0-logloss:0.01380	validation_1-logloss:0.21550
# [184]	validation_0-logloss:0.01377	validation_1-logloss:0.21524
# [185]	validation_0-logloss:0.01374	validation_1-logloss:0.21482
# [186]	validation_0-logloss:0.01371	validation_1-logloss:0.21540
# [187]	validation_0-logloss:0.01369	validation_1-logloss:0.21502
# [188]	validation_0-logloss:0.01366	validation_1-logloss:0.21476
# [189]	validation_0-logloss:0.01364	validation_1-logloss:0.21490
# [190]	validation_0-logloss:0.01361	validation_1-logloss:0.21591
# [191]	validation_0-logloss:0.01359	validation_1-logloss:0.21580
# [192]	validation_0-logloss:0.01357	validation_1-logloss:0.21544
# [193]	validation_0-logloss:0.01354	validation_1-logloss:0.21601
# [194]	validation_0-logloss:0.01352	validation_1-logloss:0.21575
# [195]	validation_0-logloss:0.01349	validation_1-logloss:0.21543
# [196]	validation_0-logloss:0.01347	validation_1-logloss:0.21510
# [197]	validation_0-logloss:0.01345	validation_1-logloss:0.21524
# [198]	validation_0-logloss:0.01343	validation_1-logloss:0.21499
# [199]	validation_0-logloss:0.01340	validation_1-logloss:0.21555
# [200]	validation_0-logloss:0.01338	validation_1-logloss:0.21569
# [201]	validation_0-logloss:0.01336	validation_1-logloss:0.21540
# [202]	validation_0-logloss:0.01334	validation_1-logloss:0.21636
# [203]	validation_0-logloss:0.01332	validation_1-logloss:0.21611
# [204]	validation_0-logloss:0.01329	validation_1-logloss:0.21577
# [205]	validation_0-logloss:0.01327	validation_1-logloss:0.21541
# [206]	validation_0-logloss:0.01325	validation_1-logloss:0.21556
# [207]	validation_0-logloss:0.01323	validation_1-logloss:0.21533
# [208]	validation_0-logloss:0.01321	validation_1-logloss:0.21505
# [209]	validation_0-logloss:0.01319	validation_1-logloss:0.21520
# [210]	validation_0-logloss:0.01317	validation_1-logloss:0.21489
# [211]	validation_0-logloss:0.01315	validation_1-logloss:0.21542
# [212]	validation_0-logloss:0.01313	validation_1-logloss:0.21518
# [213]	validation_0-logloss:0.01312	validation_1-logloss:0.21504
# [214]	validation_0-logloss:0.01310	validation_1-logloss:0.21479
# [215]	validation_0-logloss:0.01308	validation_1-logloss:0.21450
# [216]	validation_0-logloss:0.01306	validation_1-logloss:0.21502
# [217]	validation_0-logloss:0.01304	validation_1-logloss:0.21479
